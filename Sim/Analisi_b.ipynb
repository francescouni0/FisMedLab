# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt 
from scipy.stats import norm

dtype = np.float32

# %%
            
data = np.fromfile('build/detect1_110mm_b-120.0.raw',dtype=dtype) 
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
m120_1=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(m120_1)
# Out:
#              id    en[eV]   time[ns]     x[mm]     y[mm]
# 0           1.0  3.056364  10.707715 -9.038490  0.731879
# 1           1.0  3.008610   2.541534  6.464327 -1.036160
# 2           1.0  2.436499   3.822331 -1.564568  0.912216
# 3           1.0  2.705309   4.604360 -5.998631 -0.672196
# 4           1.0  2.663457   4.596328 -7.048038 -0.056667
# ...         ...       ...        ...       ...       ...
# 4595311  9998.0  2.782919   4.375740 -6.059561 -1.170056
# 4595312  9998.0  2.589753   3.293977 -2.571445  0.954321
# 4595313  9998.0  2.576952   8.757447  4.529017 -0.088428
# 4595314  9998.0  2.991297   3.666124 -5.130835  1.136693
# 4595315  9998.0  2.788261   4.221388  6.599725 -0.989095
#
# [4595316 rows x 5 columns]

# %%
data = np.fromfile('build/detect2_110mm_b-120.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
m120_2=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(m120_2)
# Out:
#              id    en[eV]  time[ns]     x[mm]     y[mm]
# 0           1.0  2.519125  2.297135  9.963854 -0.928641
# 1           1.0  2.859367  1.079888 -1.418797 -1.376315
# 2           1.0  2.884392  6.290700  3.659693 -0.776632
# 3           1.0  2.873466  5.700343 -2.340126 -1.483738
# 4           1.0  2.521402  2.821382  3.452763 -0.225538
# ...         ...       ...       ...       ...       ...
# 8479279  9998.0  2.905716  6.928098  0.742826 -0.157697
# 8479280  9998.0  2.652352  4.235133  3.163356  0.096239
# 8479281  9998.0  2.932046  1.757984  9.695251 -0.440354
# 8479282  9998.0  2.917195  4.877313  3.561619 -0.149197
# 8479283  9998.0  2.661358  2.494722 -8.458739  0.753934
#
# [8479284 rows x 5 columns]

# %%
data = np.fromfile('build/detect1_110mm_b120.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
p120_1=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(p120_1)
# Out:
#               id    en[eV]  time[ns]     x[mm]     y[mm]
# 0            1.0  2.899132  2.435301  6.174572 -0.434560
# 1            1.0  2.574847  5.612951  9.617604  1.395280
# 2            1.0  2.411905  6.482462 -1.146245 -0.299763
# 3            1.0  2.621217  1.652323 -1.603687 -1.289568
# 4            1.0  2.618075  1.677637 -4.548498  0.706992
# ...          ...       ...       ...       ...       ...
# 8546146  10000.0  2.997984  2.184776  5.137307  0.382900
# 8546147  10000.0  2.430193  1.465081  0.967282 -0.052142
# 8546148  10000.0  2.846763  2.489066  5.125052  0.260051
# 8546149  10000.0  2.691833  3.633723 -3.773887 -1.001036
# 8546150  10000.0  2.665711  2.585861 -7.638958  0.168402
#
# [8546151 rows x 5 columns]

# %%
data = np.fromfile('build/detect2_110mm_b120.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
p120_2=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(p120_2)
# Out:
#               id    en[eV]   time[ns]     x[mm]     y[mm]
# 0            1.0  2.930476   7.659819  6.425893 -0.364097
# 1            1.0  2.649803   3.496977 -9.750916  0.910359
# 2            1.0  2.923348   3.217523  5.619685 -0.778624
# 3            1.0  2.740878   5.976176 -9.488961 -0.833702
# 4            1.0  2.604782   3.862145 -0.097971  0.736750
# ...          ...       ...        ...       ...       ...
# 4622867  10000.0  3.048101   3.129383 -3.685989  0.280460
# 4622868  10000.0  2.711902   3.763954 -2.854565  0.084229
# 4622869  10000.0  2.904050   4.311500 -6.665491 -0.562666
# 4622870  10000.0  2.942993   4.334116  6.441102  0.508024
# 4622871  10000.0  2.466316  10.408746 -3.758575 -0.527550
#
# [4622872 rows x 5 columns]

# %%
data = np.fromfile('build/detect1_110mm_b160.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
1=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(p200_1)
# Out:
#                id    en[eV]  time[ns]     x[mm]     y[mm]
# 0             1.0  3.041842  3.068359  6.089568 -1.408661
# 1             1.0  2.774331  4.733057  3.298036  0.623139
# 2             1.0  2.732519  2.256860  3.724750 -0.251806
# 3             1.0  2.908897  1.697897  3.076306 -1.408158
# 4             1.0  3.085330  1.982812  9.925609  0.612291
# ...           ...       ...       ...       ...       ...
# 10670547  10000.0  2.948882  2.844567 -4.223750 -0.934864
# 10670548  10000.0  2.647568  0.700402  4.852886  1.084934
# 10670549  10000.0  2.949345  1.023703  5.820999 -1.226917
# 10670550  10000.0  2.559278  0.993797  2.171052 -0.018380
# 10670551  10000.0  2.425274  1.944203  5.135478  0.622306
#
# [10670552 rows x 5 columns]

# %%
data = np.fromfile('build/detect2_110mm_b200.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
p200_2=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(p200_2)
# Out:
#               id    en[eV]  time[ns]     x[mm]     y[mm]
# 0            1.0  2.710480  6.947208 -6.033443 -0.275926
# 1            1.0  3.093262  2.747853 -1.653989  0.699745
# 2            1.0  2.688016  4.628655  1.575390 -0.116787
# 3            1.0  2.834103  3.059493 -5.488341  0.105013
# 4            1.0  2.467049  2.814439 -9.926240  0.394967
# ...          ...       ...       ...       ...       ...
# 3798430  10000.0  2.695549  5.652098 -2.736823  1.491704
# 3798431  10000.0  2.546662  6.279634 -1.350382 -0.220951
# 3798432  10000.0  2.804562  4.289578 -3.855977 -0.803127
# 3798433  10000.0  2.814572  5.789528 -5.775627  0.884944
# 3798434  10000.0  2.729035  8.070280 -4.883026 -0.026596
#
# [3798435 rows x 5 columns]

# %%
data = np.fromfile('build/detect1_110mm_b-200.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
m200_1=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(m200_1)
# Out:
#               id    en[eV]   time[ns]     x[mm]     y[mm]
# 0            1.0  2.658599   5.802174  1.919450 -0.940376
# 1            1.0  2.864275   4.261487 -9.425266 -0.861294
# 2            1.0  2.988698   6.301760 -5.451992 -1.213470
# 3            1.0  2.881248  11.688680 -9.357800 -0.173457
# 4            1.0  2.482459   4.996477  8.064114 -0.206059
# ...          ...       ...        ...       ...       ...
# 3762914  10000.0  2.945682  11.286703 -3.984609  0.885258
# 3762915  10000.0  2.663465   8.454966 -8.805456 -0.390795
# 3762916  10000.0  2.453924   4.686403  1.845446  1.274324
# 3762917  10000.0  2.890047   4.669128 -1.643534 -1.285465
# 3762918  10000.0  3.072505   2.964669  2.146953 -0.843076
#
# [3762919 rows x 5 columns]

# %%
data = np.fromfile('build/detect2_110mm_b-200.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
m200_2=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(m200_2)
# Out:
#                id    en[eV]  time[ns]     x[mm]     y[mm]
# 0             1.0  2.716745  1.630277 -3.431119 -1.087080
# 1             1.0  3.017790  0.848314 -4.707129  0.466965
# 2             1.0  2.529810  7.539135 -0.026077  0.962882
# 3             1.0  2.829796  1.507809 -0.144920  0.116316
# 4             1.0  2.679245  1.614076 -4.480218  0.608623
# ...           ...       ...       ...       ...       ...
# 10563187  10000.0  2.885902  1.255517 -4.470799 -1.445512
# 10563188  10000.0  3.012160  2.915862 -9.705255 -0.787586
# 10563189  10000.0  2.985847  0.848164 -8.079215  1.182151
# 10563190  10000.0  2.470915  1.344510  0.750764  0.181430
# 10563191  10000.0  2.921564  1.185912 -4.041965 -0.425656
#
# [10563192 rows x 5 columns]

# %%
data = np.fromfile('build/detect2_110mm_b-80.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
m80_2=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(m80_2)
# Out:
#               id    en[eV]  time[ns]     x[mm]     y[mm]
# 0
2=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(p40_2)
# Out:
#              id    en[eV]   time[ns]     x[mm]     y[mm]
# 0           2.0  2.880463   3.955526  2.852596 -0.366464
# 1           2.0  2.870368   6.146301  3.232300 -0.961042
# 2           2.0  2.467070   6.556825  2.445452 -0.771270
# 3           2.0  3.016215   4.315678  8.202124  1.320123
# 4           2.0  2.481343   2.633173  9.433520  0.151154
# ...         ...       ...        ...       ...       ...
# 5614441  9999.0  2.400843   3.517561 -0.614992  0.396630
# 5614442  9999.0  2.870483   4.169646  6.048779  0.288682
# 5614443  9999.0  2.786464   2.303860 -0.754384 -0.575934
# 5614444  9999.0  2.788638   2.692493  8.340599 -0.181058
# 5614445  9999.0  2.669857  10.867067 -3.557071 -0.133847
#
# [5614446 rows x 5 columns]

# %%
data = np.fromfile('build/detect2_110mm_b-40.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
m40_2=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(m40_2)
# Out:
#              id    en[eV]  time[ns]     x[mm]     y[mm]
# 0           1.0  2.707070  2.937172 -2.170548 -0.648845
# 1           1.0  3.094251  9.732205  5.034828 -0.852995
# 2           1.0  2.522532  2.945480  1.413618 -0.403060
# 3           1.0  2.662618  3.412304 -1.951324 -1.134013
# 4           1.0  2.553032  4.280365 -1.240333  0.916921
# ...         ...       ...       ...       ...       ...
# 6761139  9999.0  3.062491  4.505316 -4.852367 -0.195035
# 6761140  9999.0  3.002492  1.466842  7.930617  0.242549
# 6761141  9999.0  2.424167  5.489704  6.270930  0.089245
# 6761142  9999.0  2.908536  2.636797  9.029026  1.361216
# 6761143  9999.0  2.599771  2.015643 -5.927759  1.154834
#
# [6761144 rows x 5 columns]

# %%
data = np.fromfile('build/detect1_110mm_b-40.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
m40_1=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(m40_1)
# Out:
#              id    en[eV]  time[ns]     x[mm]     y[mm]
# 0           1.0  2.672007  4.289437  6.364006  1.412707
# 1           1.0  2.814608  2.722795 -9.828163  0.919639
# 2           1.0  2.726218  5.510976 -7.250021 -1.322842
# 3           1.0  2.469925  2.545424 -9.900066  1.388938
# 4           1.0  2.561387  6.074242 -2.170699 -1.186508
# ...         ...       ...       ...       ...       ...
# 5510797  9999.0  2.714493  4.814825 -2.389458 -0.001580
# 5510798  9999.0  2.489444  5.355676  8.439151  1.425480
# 5510799  9999.0  2.899289  2.813057 -7.206065 -0.438973
# 5510800  9999.0  3.042097  2.171564  4.502852  0.533928
# 5510801  9999.0  2.432769  3.161387 -2.790158 -1.096865
#
# [5510802 rows x 5 columns]

# %%
data = np.fromfile('build/detect1_110mm_b40.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
p40_1=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(p40_1)
# Out:
#              id    en[eV]  time[ns]     x[mm]     y[mm]
# 0           2.0  2.427762  1.948801  1.871738  1.270378
# 1           2.0  2.560553  2.078026  5.420521 -0.858836
# 2           2.0  2.410839  2.257785  0.893360  1.153671
# 3           2.0  2.638715  4.948773 -8.657524 -0.541045
# 4           2.0  2.828656  1.775207  8.854744 -0.777250
# ...         ...       ...       ...       ...       ...
# 6877057  9999.0  2.645879  4.090251  0.684277  1.395337
# 6877058  9999.0  3.083419  2.264247  2.151857 -0.220919
# 6877059  9999.0  2.692575  6.299494 -3.683805 -0.118539
# 6877060  9999.0  2.657785  2.251238  0.268463  1.009887
# 6877061  9999.0  2.700682  3.710090  9.108910  0.467514
#
# [6877062 rows x 5 columns]

# %%
data = np.fromfile('build/detect1_110mm_b0.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
p0_1=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(p0_1)
# Out:
#               id    en[eV]  time[ns]     x[mm]     y[mm]
# 0            1.0  2.625193  3.621445  1.990778 -1.486160
# 1            1.0  3.095063  2.565586  7.001553  0.371075
# 2            1.0  2.794525  3.996981 -2.311466  0.862728
# 3            1.0  2.734930  2.012240  3.912565 -1.327456
# 4            1.0  2.454634  6.670350  0.474441 -0.659433
# ...          ...       ...       ...       ...       ...
# 6089397  10000.0  2.628986  3.954213 -0.855752  0.206696
# 6089398  10000.0  2.773141  4.097221 -3.911119 -0.201596
# 6089399  10000.0  2.878106  2.962322  5.291073 -0.492380
# 6089400  10000.0  2.417424  3.655376  0.578134 -0.167776
# 6089401  10000.0  2.661209  3.873329  3.243964 -0.814065
#
# [6089402 rows x 5 columns]

# %%
data = np.fromfile('build/detect2_110mm_b0.0.raw', dtype=dtype)
# Reshape the array into three columns
num_cols = 5
num_rows = len(data) // num_cols
data = data.reshape((num_rows, num_cols))

# Access the columns as separate arrays
col1 = data[:, 0]
col2 = data[:, 1]
col3 = data[:, 2]
col4 = data[:, 3]
col5 = data[:, 4]  # Replace with your own data extraction logic

# Append extracted data to the column data
p0_2=pd.DataFrame(data, columns=['id','en[eV]','time[ns]','x[mm]','y[mm]'])  

print(p0_2)
# Out:
#               id    en[eV]   time[ns]     x[mm]     y[mm]
# 0            1.0  2.794499   3.193252  1.114367 -0.235868
# 1            1.0  2.554726  16.030951 -6.235402 -0.253792
# 2            1.0  2.860323   4.865337  7.797153  0.414021
# 3            1.0  2.876266   3.783854 -5.400047 -0.658663
# 4            1.0  3.010805   3.894467 -5.739312 -0.043098
# ...          ...       ...        ...       ...       ...
# 6092587  10000.0  3.088259   2.035440 -5.753031  0.982100
# 6092588  10000.0  2.849226  11.810623 -9.732695 -0.295791
# 6092589  10000.0  3.056365   5.968937 -2.434230  1.057830
# 6092590  10000.0  2.853025   6.519225 -9.273480 -0.986058
# 6092591  10000.0  2.636031   3.338571  1.332210 -1.297173
#
# [6092592 rows x 5 columns]

# %%
mean=[]
mean_1=[]

std=[]
std_1=[]

# %%
from scipy.optimize import curve_fit    

def gaussian(x, a, x0, sigma):
    return a*np.exp(-(x-x0)**2/(2*sigma**2))

tm200=(m200_1.iloc[:,2]-m200_2.iloc[:,2])
tm200=tm200


n,bins,_=plt.hist(tm200,bins='auto', alpha=0.5, label='Histogram')

bin_centers = (bins[:-1] + bins[1:]) / 2


# Fit the histogram using curve_fit
fit_params, _ = curve_fit(gaussian, bin_centers, n,p0=[np.max(n),np.mean(tm200),np.std(tm200)])

# Generate x values for plotting the fitted distribution
x = np.linspace(np.min(bin_centers), np.max(bin_centers), 100000)


# Plot the fitted distribution
plt.plot(x, gaussian(x, *fit_params), 'r-', label='Fitted Distribution')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''
plt.plot(x,gaussian(x,20000,0,0.15), 'g-', label='prova')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''

print(fit_params)
mean=np.append(mean,fit_params[1])
mean_1=np.append(mean_1,np.mean(tm200))
std=np.append(std,fit_params[2])  

std_1=np.append(std_1,np.std(tm200))
# Out:
# [2.56652069e+04 2.77800042e+00 2.26838519e+00]

# %%
tm160=(m160_1.iloc[:,2]-m160_2.iloc[:,2])
tm160=tm160


n,bins,_=plt.hist(tm160,bins='auto', alpha=0.5, label='Histogram')

bin_centers = (bins[:-1] + bins[1:]) / 2


# Fit the histogram using curve_fit
fit_params, _ = curve_fit(gaussian, bin_centers, n,p0=[np.max(n),np.mean(tm160),np.std(tm160)])

# Generate x values for plotting the fitted distribution
x = np.linspace(np.min(bin_centers), np.max(bin_centers), 100000)


# Plot the fitted distribution
plt.plot(x, gaussian(x, *fit_params), 'r-', label='Fitted Distribution')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''
plt.plot(x,gaussian(x,20000,0,0.15), 'g-', label='prova')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''

print(fit_params)
mean=np.append(mean,fit_params[1])
mean_1=np.append(mean_1,np.mean(tm160))
std=np.append(std,fit_params[2])  

std_1=np.append(std_1,np.std(tm160))
# Out:
# [2.77929754e+04 2.20635879e+00 2.26529401e+00]

# %%
tm120=(m120_1.iloc[:,2]-m120_2.iloc[:,2])
tm120=tm120


n,bins,_=plt.hist(tm120,bins='auto', alpha=0.5, label='Histogram')

bin_centers = (bins[:-1] + bins[1:]) / 2


# Fit the histogram using curve_fit
fit_params, _ = curve_fit(gaussian, bin_centers, n,p0=[np.max(n),np.mean(tm120),np.std(tm120)])

# Generate x values for plotting the fitted distribution
x = np.linspace(np.min(bin_centers), np.max(bin_centers), 100000)


# Plot the fitted distribution
plt.plot(x, gaussian(x, *fit_params), 'r-', label='Fitted Distribution')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''
plt.plot(x,gaussian(x,20000,0,0.15), 'g-', label='prova')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''

print(fit_params)
mean=np.append(mean,fit_params[1])
mean_1=np.append(mean_1,np.mean(tm120))
std=np.append(std,fit_params[2])  

std_1=np.append(std_1,np.std(tm120))
# Out:
# [2.93157640e+04 1.63976743e+00 2.27195120e+00]

# %%
tm80=(m80_1.iloc[:,2]-m80_2.iloc[:,2])
tm80=tm80


n,bins,_=plt.hist(tm80,bins='auto', alpha=0.5, label='Histogram')

bin_centers = (bins[:-1] + bins[1:]) / 2


# Fit the histogram using curve_fit
fit_params, _ = curve_fit(gaussian, bin_centers, n,p0=[np.max(n),np.mean(tm80),np.std(tm80)])

# Generate x values for plotting the fitted distribution
x = np.linspace(np.min(bin_centers), np.max(bin_centers), 100000)


# Plot the fitted distribution
plt.plot(x, gaussian(x, *fit_params), 'r-', label='Fitted Distribution')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''
plt.plot(x,gaussian(x,20000,0,0.15), 'g-', label='prova')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''

print(fit_params)
mean=np.append(mean,fit_params[1])
mean_1=np.append(mean_1,np.mean(tm80))
std=np.append(std,fit_params[2])  

std_1=np.append(std_1,np.std(tm80))
# Out:
# [3.13860974e+04 1.08813757e+00 2.28249838e+00]

# %%
tm40=(m40_1.iloc[:,2]-m40_2.iloc[:,2])
tm40=tm40


n,bins,_=plt.hist(tm40,bins='auto', alpha=0.5, label='Histogram')

bin_centers = (bins[:-1] + bins[1:]) / 2


# Fit the histogram using curve_fit
fit_params, _ = curve_fit(gaussian, bin_centers, n,p0=[np.max(n),np.mean(tm40),np.std(tm40)])

# Generate x values for plotting the fitted distribution
x = np.linspace(np.min(bin_centers), np.max(bin_centers), 100000)


# Plot the fitted distribution
plt.plot(x, gaussian(x, *fit_params), 'r-', label='Fitted Distribution')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''
plt.plot(x,gaussian(x,20000,0,0.15), 'g-', label='prova')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''

print(fit_params)
mean=np.append(mean,fit_params[1])
mean_1=np.append(mean_1,np.mean(tm40))
std=np.append(std,fit_params[2])  

std_1=np.append(std_1,np.std(tm40))
# Out:
# [3.30630315e+04 5.41718606e-01 2.28517505e+00]

# %%
t0=(p0_1.iloc[:,2]-p0_2.iloc[:,2])
t0=t0


n,bins,_=plt.hist(t0,bins='auto', alpha=0.5, label='Histogram')

bin_centers = (bins[:-1] + bins[1:]) / 2


# Fit the histogram using curve_fit
fit_params, _ = curve_fit(gaussian, bin_centers, n,p0=[np.max(n),np.mean(t0),np.std(t0)])

# Generate x values for plotting the fitted distribution
x = np.linspace(np.min(bin_centers), np.max(bin_centers), 100000)


# Plot the fitted distribution
plt.plot(x, gaussian(x, *fit_params), 'r-', label='Fitted Distribution')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''
plt.plot(x,gaussian(x,20000,0,0.15), 'g-', label='prova')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''

print(fit_params)
mean=np.append(mean,fit_params[1])
mean_1=np.append(mean_1,np.mean(t0))
std=np.append(std,fit_params[2])  

std_1=np.append(std_1,np.std(t0))
# Out:
# [3.53458697e+04 1.35317756e-03 2.28825482e+00]

# %%
    

tp40=(p40_1.iloc[:,2]-p40_2.iloc[:,2])
tp40=tp40


n,bins,_=plt.hist(tp40,bins='auto', alpha=0.5, label='Histogram')

bin_centers = (bins[:-1] + bins[1:]) / 2


# Fit the histogram using curve_fit
fit_params, _ = curve_fit(gaussian, bin_centers, n,p0=[np.max(n),np.mean(tp40),np.std(tp40)])

# Generate x values for plotting the fitted distribution
x = np.linspace(np.min(bin_centers), np.max(bin_centers), 100000)


# Plot the fitted distribution
plt.plot(x, gaussian(x, *fit_params), 'r-', label='Fitted Distribution')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''
plt.plot(x,gaussian(x,20000,0,0.15), 'g-', label='prova')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''

print(fit_params)

mean=np.append(mean,fit_params[1])

mean_1=np.append(mean_1,np.mean(tp40))

std=np.append(std,fit_params[2])  

std_1=np.append(std_1,np.std(tp40))
# Out:
# [ 3.34684042e+04 -5.42185181e-01  2.28730270e+00]

# %%
tp80=(p80_1.iloc[:,2]-p80_2.iloc[:,2])
tp80=tp80


n,bins,_=plt.hist(tp80,bins='auto', alpha=0.5, label='Histogram')

bin_centers = (bins[:-1] + bins[1:]) / 2


# Fit the histogram using curve_fit
fit_params, _ = curve_fit(gaussian, bin_centers, n,p0=[np.max(n),np.mean(tp80),np.std(tp80)])

# Generate x values for plotting the fitted distribution
x = np.linspace(np.min(bin_centers), np.max(bin_centers), 100000)


# Plot the fitted distribution
plt.plot(x, gaussian(x, *fit_params), 'r-', label='Fitted Distribution')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''
plt.plot(x,gaussian(x,20000,0,0.15), 'g-', label='prova')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''

print(fit_params)
mean=np.append(mean,fit_params[1])
mean_1=np.append(mean_1,np.mean(tp80))
std=np.append(std,fit_params[2])  

std_1=np.append(std_1,np.std(tp80))
# Out:
# [ 3.11883091e+04 -1.08022759e+00  2.28031370e+00]

# %%
tp120=(p120_1.iloc[:,2]-p120_2.iloc[:,2])
tp120=tp120


n,bins,_=plt.hist(tp120,bins='auto', alpha=0.5, label='Histogram')

bin_centers = (bins[:-1] + bins[1:]) / 2


# Fit the histogram using curve_fit
fit_params, _ = curve_fit(gaussian, bin_centers, n,p0=[np.max(n),np.mean(tp120),np.std(tp120)])

# Generate x values for plotting the fitted distribution
x = np.linspace(np.min(bin_centers), np.max(bin_centers), 100000)


# Plot the fitted distribution
plt.plot(x, gaussian(x, *fit_params), 'r-', label='Fitted Distribution')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''
plt.plot(x,gaussian(x,20000,0,0.15), 'g-', label='prova')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''

print(fit_params)
mean=np.append(mean,fit_params[1])
mean_1=np.append(mean_1,np.mean(tp120))
std=np.append(std,fit_params[2])  

std_1=np.append(std_1,np.std(tp120))
# Out:
# [ 2.94161692e+04 -1.63932042e+00  2.27287350e+00]

# %%
tp160=(p160_1.iloc[:,2]-p160_2.iloc[:,2])
tp160=tp160


n,bins,_=plt.hist(tp160,bins='auto', alpha=0.5, label='Histogram')

bin_centers = (bins[:-1] + bins[1:]) / 2


# Fit the histogram using curve_fit
fit_params, _ = curve_fit(gaussian, bin_centers, n,p0=[np.max(n),np.mean(tp160),np.std(tp160)])

# Generate x values for plotting the fitted distribution
x = np.linspace(np.min(bin_centers), np.max(bin_centers), 100000)


# Plot the fitted distribution
plt.plot(x, gaussian(x, *fit_params), 'r-', label='Fitted Distribution')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''
plt.plot(x,gaussian(x,20000,0,0.15), 'g-', label='prova')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''

print(fit_params)
mean=np.append(mean,fit_params[1])
mean_1=np.append(mean_1,np.mean(tp160))
std=np.append(std,fit_params[2])  

std_1=np.append(std_1,np.std(tp160))
# Out:
# [ 2.73656831e+04 -2.20017656e+00  2.26329664e+00]

# %%
tp200=(p200_1.iloc[:,2]-p200_2.iloc[:,2])
tp200=tp200


n,bins,_=plt.hist(tp200,bins='auto', alpha=0.5, label='Histogram')

bin_centers = (bins[:-1] + bins[1:]) / 2


# Fit the histogram using curve_fit
fit_params, _ = curve_fit(gaussian, bin_centers, n,p0=[np.max(n),np.mean(tp200),np.std(tp200)])

# Generate x values for plotting the fitted distribution
x = np.linspace(np.min(bin_centers), np.max(bin_centers), 100000)


# Plot the fitted distribution
plt.plot(x, gaussian(x, *fit_params), 'r-', label='Fitted Distribution')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''
plt.plot(x,gaussian(x,20000,0,0.15), 'g-', label='prova')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
'''

print(fit_params)
mean=np.append(mean,fit_params[1])
mean_1=np.append(mean_1,np.mean(tp200))
std=np.append(std,fit_params[2])  

std_1=np.append(std_1,np.std(tp200))
# Out:
# [ 2.58211089e+04 -2.78054157e+00  2.26768495e+00]

# %%
D=np.array([200,160,120,80,40,0,-40,-80,-120,-160,-200])


plt.errorbar(D,mean,yerr=np.sqrt(std)/4,fmt='.',label='fit')
plt.legend()
plt.show()

# %%
s=(std/np.sqrt(len(tp40)))*1e-9
mean=mean*1e-9

# %%
def linear(x, a, b):
    return a * 2*x + b




# Read data from a file
x2=np.array(D,dtype=float)
x2=(x2)/1000

y=np.array(mean,dtype=float)

# Fit linear model with curve_fit
popt, pcov = curve_fit(linear, x2, y,sigma=s,absolute_sigma=True)

# Print fitted parameters and covariance matrix
print("Fitted parameters:\n", popt)
print("Covariance matrix:\n", pcov)

# Plot scatter plot and fitted line
plt.errorbar(x2, y,yerr=1e-10, fmt='.',color='cyan', label="Data")
plt.xlabel("$D_1 - D_2$ [m]")
plt.ylabel("$t_1 - t_2$ [s]")
plt.title("$\Delta t$ vs. $\Delta x$")

xmin, xmax = plt.xlim()
ymin, ymax = linear(xmin, *popt), linear(xmax, *popt)
plt.plot([xmin, xmax], [ymin, ymax], 'magenta', label="Fitted line")
plt.legend()
plt.show()

residuals = y- linear(x2, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((mean-np.mean(mean))**2)
r_squared = 1 - (ss_res / ss_tot)
print('R^2 =',r_squared)

'''
speed=[]

for i in range(9):
    speed=np.append(speed,np.absolute((D[9-i]/(T[i]-T[9-i]))*1e-2))

speed_mean=np.mean(speed)


n=(2.99792458e+08)/speed_mean
print(speed_mean,'[m/s]')
print(n)
'''

speed = (1/popt[0])
err_speed = np.sqrt(pcov[0,0])/(popt[0])**2
n = (2.99792458e+08)/speed
err_n = np.abs(err_speed/(speed)**2)*(2.99792458e+08)

print(f'Light speed:\n ({speed: .4e} +/- {err_speed: .0e}) m/s')
print(f'Refraction index:\n {n: .3f} +/- {err_n: .3f}')
# Out:
# Fitted parameters:
#  [6.89524930e-09 1.17086365e-12]
# Covariance matrix:
#  [[1.06334508e-24 7.54877722e-29]
#  [7.54877722e-29 6.84580200e-26]]
# R^2 = 0.9999300876492514
# Light speed:
#  ( 1.4503e+08 +/-  2e+04) m/s
# Refraction index:
#   2.067 +/-  0.000
