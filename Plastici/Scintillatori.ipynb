# %% [markdown]
# Calcolo differenza risoluzione temporale al variare della OV, dati a 22 cm per cfd 80 a vari over voltage

# %%
import matplotlib.pyplot as plt
import numpy as np

# Read data from a file

data_108 = np.loadtxt("F1--V_108_CFD_80_22cm_ch34.txt",delimiter=',')
data_110 = np.loadtxt("F1--V_110_CFD_80_22cm_ch34.txt",delimiter=',')
data_112 = np.loadtxt("F1--V_112_CFD_80_22cm_ch34.txt",delimiter=',')
data_114 = np.loadtxt("F1--V_114_CFD_80_22cm_ch34.txt",delimiter=',')
data_116 = np.loadtxt("F1--V_116_CFD_80_22cm_ch34.txt",delimiter=',')
data_118 = np.loadtxt("F1--V_118_CFD_80_22cm_ch34.txt",delimiter=',')
data_120 = np.loadtxt("F1--V_120_CFD_80_22cm_ch34.txt",delimiter=',')



# Extract times and counts
times_108 = data_108[:, 0]
counts_108 = data_108[:, 1]
times_110 = data_110[:, 0]
counts_110 = data_110[:, 1]
times_112 = data_112[:, 0]
counts_112 = data_112[:, 1]
times_114 = data_114[:, 0]
counts_114 = data_114[:, 1]
times_116 = data_116[:, 0]
counts_116 = data_116[:, 1]
times_118 = data_118[:, 0]
counts_118 = data_118[:, 1]
times_120 = data_120[:, 0]
counts_120 = data_120[:, 1]

# Plot histogram
fig = plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)

plt.subplot(3, 3, 1)
plt.hist(times_108, weights=counts_108, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("108")

plt.subplot(3, 3, 2)
plt.hist(times_110, weights=counts_110, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("110")

plt.subplot(3, 3, 3)
plt.hist(times_112, weights=counts_112, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("112")

plt.subplot(3, 3, 4)
plt.hist(times_114, weights=counts_114, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("114")

plt.subplot(3, 3, 5)
plt.hist(times_116, weights=counts_116, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("116")

plt.subplot(3, 3, 6)
plt.hist(times_118, weights=counts_118, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("118")

plt.subplot(3, 3, 8)
plt.hist(times_120, weights=counts_120, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("120")

# Adjust spacing
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# 108

# %%
from scipy.optimize import curve_fit
from scipy.stats import chisquare



# Define gaussian function
def gaussian(x, a, b, c):
    return a * np.exp(-((x - b) / c) ** 2)

V=[108,110,112,114,116,118,120]
counts=np.stack([counts_108,counts_110,counts_112,counts_114,counts_116,counts_118,counts_120],axis=0)
times=np.stack([times_108,times_110,times_112,times_114,times_116,times_118,times_120],axis=0)

print(np.shape(counts))
#SONO OTTIMIZZABILI
p0_list=[(95,-4.17995274e-11,0.3318e-9),(1.07605056e+02, -2.04905536e-11 , 3.03266025e-10),(9.76907093e+01, -9.02490361e-12,  2.91871235e-10),(9.76792576e+01, -7.66294285e-12,  2.88231386e-10),(9.54787027e+01, 4.51361278e-12 ,2.96036116e-10),(1.00941906e+02, 2.03798281e-12, 2.89832761e-10),(9.54787027e+01, 4.51361278e-12 ,2.96036116e-10)]

s=[]
ds=[]
T=[]
dT=[]

for i in range(7):
    
    
    sigma1=[np.var(counts[i,:])]*200
    # Fit gaussian function with curve_fit
    # Use bounds to fix b to 0 and let a and c vary
    popt, pcov = curve_fit(gaussian, times[i,:], counts[i,:],p0=p0_list[i],sigma=sigma1,absolute_sigma=False)
    
    # Print fitted parameters and covariance matrix
    print("Fitted parameters:", popt)
    print("Covariance matrix:", pcov)
    s=np.append(s,popt[2])
    T=np.append(T,popt[0])
    ds=np.append(ds,np.sqrt(pcov[2,2]))
    dT=np.append(dT,np.sqrt(pcov[0,0]))
    # Plot histogram and fitted function
    plt.hist(times[i,:], weights=counts[i,:], bins=200,)
    plt.xlabel("Time")
    plt.ylabel("Count")
    plt.title(f"Histogram of times{V[i]} and counts{V[i]}")
    
    x = np.linspace(min(times[i,:]), max(times[i,:]), 1000)
    y = gaussian(x, *popt)
    plt.plot(x, y, 'r-', label="Fitted curve")
    '''
    x_test = np.linspace(min(times[i,:]), max(times[i,:]), 1000)
    y_test = gaussian(x,1.75000000e+02,-0,2.15270818e-10 )
    plt.plot(x_test, y_test, 'y-', label="Fitted curve")
    plt.legend()
    plt.show()
    '''
    
    
    # Calculate expected frequencies from fitted function
    expected = gaussian(times[i,:], *popt)
    # Scale expected frequencies by ratio of sums
    ratio = sum(counts[i,:]) / sum(expected)
    expected = expected * ratio
    
    
    # Calculate chisquare and p-value
    chisq, p = chisquare(counts[i,:], expected)
    
    
    
    # Print results
    print("Chisquare:", chisq)
    print("P-value:", p)
    
    # Calculate chisquare reduced
    
    dof= len(times[i,:]) - 3
    print(dof)
    chisq_red = chisq / dof
    print("Chisquare reduced:", chisq_red)
    plt.show()
# Out:
# (7, 200)
# Fitted parameters: [ 9.32984059e+01 -4.17995329e-11  3.07448636e-10]
# Covariance matrix: [[ 9.74220456e-01 -1.38122972e-20 -2.14023298e-12]
#  [-1.38122972e-20  7.05271066e-24  2.04846610e-31]
#  [-2.14023298e-12  2.04846610e-31  1.41054222e-23]]
# Chisquare: 419.8881739592291
# P-value: 7.075179345867174e-18
# 197
# Chisquare reduced: 2.1314120505544625
# Fitted parameters: [ 1.07605057e+02 -2.04905521e-11  3.03266020e-10]
# Covariance matrix: [[ 1.16157005e+00  4.56785183e-20 -2.18245478e-12]
#  [ 4.56785183e-20  6.15086632e-24 -1.23960140e-31]
#  [-2.18245478e-12 -1.23960140e-31  1.23017342e-23]]
# Chisquare: 268.7537002589717
# P-value: 0.000716628292634031
# 197
# Chisquare reduced: 1.3642319810100088
# Fitted parameters: [ 9.76906964e+01 -9.02489035e-12  2.91871311e-10]
# Covariance matrix: [[ 1.08209060e+00  7.78166735e-21 -2.15531326e-12]
#  [ 7.78166735e-21  6.43944572e-24  1.08631979e-33]
#  [-2.15531326e-12  1.08631979e-33  1.28788900e-23]]
# Chisquare: 658.513674258065
# P-value: 1.461167829609864e-50
# 197
# Chisquare reduced: 3.3427090063861167
# Fitted parameters: [ 9.76792600e+01 -7.66294811e-12  2.88231371e-10]
# Covariance matrix: [[ 1.13589494e+00 -6.02309091e-20 -2.23452813e-12]
#  [-6.02309091e-20  6.59363209e-24  4.01996033e-31]
#  [-2.23452813e-12  4.01996033e-31  1.31872653e-23]]
# Chisquare: 422.63632009249693
# P-value: 3.3856512916364294e-18
# 197
# Chisquare reduced: 2.1453620309263806
# Fitted parameters: [1.97982745e+02 9.36571824e-12 2.84337078e-10]
# Covariance matrix: [[ 1.97752809e+00  8.88737706e-20 -1.89338147e-12]
#  [ 8.88737706e-20  2.71922268e-24  1.53569566e-31]
#  [-1.89338147e-12  1.53569566e-31  5.43844570e-24]]
# Chisquare: 256.1834824200523
# P-value: 0.0038729891585909814
# 197
# Chisquare reduced: 1.300423768629707
# Fitted parameters: [1.00941887e+02 2.03796622e-12 2.89832870e-10]
# Covariance matrix: [[ 1.00955732e+00  2.33387449e-19 -1.93248306e-12]
#  [ 2.33387449e-19  5.54870364e-24 -1.15872766e-31]
#  [-1.93248306e-12 -1.15872766e-31  1.10974110e-23]]
# Chisquare: 421.65751638383006
# P-value: 4.404064876578313e-18
# 197
# Chisquare reduced: 2.1403934841818786
# Fitted parameters: [9.54786901e+01 4.51366085e-12 2.96036195e-10]
# Covariance matrix: [[ 1.08883619e+00  4.37296599e-19 -2.25065843e-12]
#  [ 4.37296599e-19  6.97826864e-24 -1.24501398e-30]
#  [-2.25065843e-12 -1.24501398e-30  1.39565407e-23]]
# Chisquare: 2817.963923764965
# P-value: 0.0
# 197
# Chisquare reduced: 14.304385399822158

# %%
def linear(x, a, b):
    return a * x + b
# Read data from a file

x=V[0:5]
y=s[0:5]

# Fit linear model with curve_fit
popt, pcov = curve_fit(linear, x, y,sigma=ds[0:5],absolute_sigma=True)

# Print fitted parameters and covariance matrix
print("Fitted parameters:", popt)
print("Covariance matrix:", pcov)

# Plot scatter plot and fitted line
plt.errorbar(V[0:5], s[0:5],yerr=ds[0:5], fmt='o')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear regression fit")

xmin, xmax = plt.xlim()
ymin, ymax = linear(xmin, *popt), linear(xmax, *popt)
plt.plot([xmin, xmax], [ymin, ymax], 'r')

z=V[5:7]
w=s[5:7]

# Fit linear model with curve_fit
popt, pcov = curve_fit(linear, z, w,sigma=ds[5:7],absolute_sigma=True)

# Print fitted parameters and covariance matrix
print("Fitted parameters:", popt)
print("Covariance matrix:", pcov)

# Plot scatter plot and fitted line
plt.errorbar(z, w,yerr=ds[5:7], fmt='o')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear regression fit")

xmin, xmax = 116,120
ymin, ymax = linear(xmin, *popt), linear(xmax, *popt)
plt.plot([xmin, xmax], [ymin, ymax], 'm')
plt.show()



'''
# Calculate residuals
res = w - linear(z, *popt)

# Calculate sum of squares of residuals
ss_res = np.sum(res ** 2)

# Calculate total sum of squares
ss_tot = np.sum((y - np.mean(y)) ** 2)

# Calculate R-squared
r_squared = 1 - (ss_res / ss_tot)

# Print R-squared
print("R-squared:", r_squared)

'''
# Out:
# Fitted parameters: [-2.94741649e-12  6.25391442e-10]
# Covariance matrix: [[ 2.32151806e-25 -2.62101405e-23]
#  [-2.62101405e-23  2.96119037e-21]]
# Fitted parameters: [ 3.10166225e-12 -7.61632756e-11]
# Covariance matrix: [[ 6.26352572e-24 -7.44644767e-22]
#  [-7.44644767e-22  8.85339304e-20]]
# '\n# Calculate residuals\nres = w - linear(z, *popt)\n\n# Calculate sum of squares of residuals\nss_res = np.sum(res ** 2)\n\n# Calculate total sum of squares\nss_tot = np.sum((y - np.mean(y)) ** 2)\n\n# Calculate R-squared\nr_squared = 1 - (ss_res / ss_tot)\n\n# Print R-squared\nprint("R-squared:", r_squared)\n\n'

# %% [markdown]
# In funzione diversi CFD

# %%
# Read data from a file

data_20 = np.loadtxt("F1--V_116_CFD_20_22cm_ch34.txt",delimiter=',')
data_30 = np.loadtxt("F1--V_116_CFD_30_22cm_ch34.txt",delimiter=',')
data_40 = np.loadtxt("F1--V_116_CFD_40_22cm_ch34.txt",delimiter=',')
data_50 = np.loadtxt("F1--V_116_CFD_50_22cm_ch34.txt",delimiter=',')
data_60 = np.loadtxt("F1--V_116_CFD_60_22cm_ch34.txt",delimiter=',')
data_70 = np.loadtxt("F1--V_116_CFD_70_22cm_ch34.txt",delimiter=',')
data_80 = np.loadtxt("F1--V_116_CFD_80_22cm_ch34.txt",delimiter=',')



# Extract times and counts
times_20 = data_20[:, 0]
counts_20 = data_20[:, 1]
times_30 = data_30[:, 0]
counts_30 = data_30[:, 1]
times_40 = data_40[:, 0]
counts_40 = data_40[:, 1]
times_50 = data_50[:, 0]
counts_50 = data_50[:, 1]
times_60 = data_60[:, 0]
counts_60 = data_60[:, 1]
times_70 = data_70[:, 0]
counts_70 = data_70[:, 1]
times_80 = data_80[:, 0]
counts_80 = data_80[:, 1]

# Plot histogram
fig = plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)

plt.subplot(3, 3, 1)
plt.hist(times_20, weights=counts_20, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("20 CFD")

plt.subplot(3, 3, 2)
plt.hist(times_30, weights=counts_30, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("30 CFD")

plt.subplot(3, 3, 3)
plt.hist(times_40, weights=counts_40, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("40 CFD")

plt.subplot(3, 3, 4)
plt.hist(times_50, weights=counts_50, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("50 CFD")

plt.subplot(3, 3, 5)
plt.hist(times_60, weights=counts_60, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("60 CFD")

plt.subplot(3, 3, 6)
plt.hist(times_70, weights=counts_70, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("70 CFD")

plt.subplot(3, 3, 8)
plt.hist(times_80, weights=counts_80, bins=100)
plt.xlabel("Time [s]")
plt.ylabel("Count")
plt.title("80 CFD")

# Adjust spacing
plt.tight_layout()

# Show plot
plt.show()

# %%
from scipy.optimize import curve_fit
from scipy.stats import chisquare



# Define gaussian function
def gaussian(x, a, b, c):
    return a * np.exp(-((x - b) / c) ** 2)

CFD=[20,30,40,50,60,70,80]
counts=np.stack([counts_20,counts_30,counts_40,counts_50,counts_60,counts_70,counts_80],axis=0)
times=np.stack([times_20,times_30,times_40,times_50,times_60,times_70,times_80],axis=0)

print(np.shape(counts))

p0_list=[(140,5.17995274e-11,0.3318e-9),(140, 2.04905536e-11 , 3.03266025e-11),(128, 9.02490361e-12,  2.91871235e-10),(140, 7.66294285e-12,  2.88231386e-10),(97,9.36570895e-12, 2.84337087e-10),(100, 2.03798281e-12, 2.89832761e-10),(140, 4.51361278e-12 ,2.96036116e-10)]

s=[]
ds=[]
T=[]
dT=[]

for i in range(7):
    
    if i<=3:
        sigma1=[np.var(counts[i,:])/30]*200
    else:
        sigma1=[np.sqrt(np.mean(counts[i,:]))]*200
    
    # Fit gaussian function with curve_fit
    # Use bounds to fix b to 0 and let a and c vary
    popt, pcov = curve_fit(gaussian, times[i,:], counts[i,:],p0=p0_list[i],sigma=sigma1,absolute_sigma=True)
    
    # Print fitted parameters and covariance matrix
    print("Fitted parameters:", popt)
    print("Covariance matrix:", pcov)
    s=np.append(s,popt[2])
    T=np.append(T,popt[0])
    ds=np.append(ds,np.sqrt(pcov[2,2]))
    dT=np.append(dT,np.sqrt(pcov[0,0]))
    # Plot histogram and fitted function
    plt.hist(times[i,:], weights=counts[i,:], bins=200,)
    plt.xlabel("Time")
    plt.ylabel("Count")
    plt.title(f"Histogram of times{CFD[i]} and counts{CFD[i]}")
    
    x = np.linspace(min(times[i,:]), max(times[i,:]), 1000)
    y = gaussian(x, *popt)
    plt.plot(x, y, 'r-', label="Fitted curve")
    '''
    x_test = np.linspace(min(times[i,:]), max(times[i,:]), 1000)
    y_test = gaussian(x,1.75000000e+02,-0,2.15270818e-10 )
    plt.plot(x_test, y_test, 'y-', label="Fitted curve")
    plt.legend()
    plt.show()
    '''
    
    
    # Calculate expected frequencies from fitted function
    expected = gaussian(times[i,:], *popt)
    # Scale expected frequencies by ratio of sums
    ratio = sum(counts[i,:]) / sum(expected)
    expected = expected * ratio
    
    
    # Calculate chisquare and p-value
    chisq, p = chisquare(counts[i,:], expected)
    
    
    
    # Print results
    print("Chisquare:", chisq)
    print("P-value:", p)
    
    # Calculate chisquare reduced
    
    dof= len(times[i,:]) - 3
    print(dof)
    chisq_red = chisq / dof
    print("Chisquare reduced:", chisq_red)
    plt.show()
# Out:
# (7, 200)
# Fitted parameters: [1.39202259e+02 5.65599534e-11 1.00356126e-09]
# Covariance matrix: [[ 2.19716204e+02  2.88552774e-17 -1.05600852e-09]
#  [ 2.88552774e-17  7.61314444e-21 -3.55419809e-30]
#  [-1.05600852e-09 -3.55419809e-30  1.52262873e-20]]
# Chisquare: 305807.6396000471
# P-value: 0.0
# 197
# Chisquare reduced: 1552.3230436550614
# Fitted parameters: [1.28515988e+02 1.10973105e-10 1.09136382e-09]
# Covariance matrix: [[ 1.64821610e+02 -7.92175785e-18 -9.33105127e-10]
#  [-7.92175785e-18  7.92388699e-21  7.37676878e-29]
#  [-9.33105127e-10  7.37676878e-29  1.58477738e-20]]
# Chisquare: 10389438.390573902
# P-value: 0.0
# 197
# Chisquare reduced: 52738.2659419995
# Fitted parameters: [2.39430104e+02 4.38436045e-11 5.75456472e-10]
# Covariance matrix: [[ 1.39968936e+03  1.65133565e-17 -2.24275107e-09]
#  [ 1.65133565e-17  5.39040917e-21 -3.27609457e-29]
#  [-2.24275107e-09 -3.27609457e-29  1.07808187e-20]]
# Chisquare: 263129787800004.88
# P-value: 0.0
# 197
# Chisquare reduced: 1335684202030.4817
# Fitted parameters: [1.74688520e+02 2.27814890e-11 3.90910649e-10]
# Covariance matrix: [[ 4.85420844e+02 -3.42266251e-18 -7.24189424e-10]
#  [-3.42266251e-18  1.62060513e-21  1.09634546e-29]
#  [-7.24189424e-10  1.09634546e-29  3.24121019e-21]]
# Chisquare: 3.190286691558635e+17
# P-value: 0.0
# 197
# Chisquare reduced: 1619434868811489.8
# Fitted parameters: [8.59492779e+01 1.95715127e-11 3.26544868e-10]
# Covariance matrix: [[ 9.24559495e-01  4.63382762e-17 -2.34191367e-12]
#  [ 4.63382762e-17  8.89670762e-24 -3.81606391e-28]
#  [-2.34191367e-12 -3.81606391e-28  1.77951665e-23]]
# Chisquare: 7524.996911379919
# P-value: 0.0
# 197
# Chisquare reduced: 38.19795386487269
# Fitted parameters: [9.67322815e+01 1.95684787e-11 2.92566937e-10]
# Covariance matrix: [[ 1.03148988e+00  9.86425724e-20 -2.07982958e-12]
#  [ 9.86425724e-20  6.29044870e-24 -6.50885963e-31]
#  [-2.07982958e-12 -6.50885963e-31  1.25809007e-23]]
# Chisquare: 906.8522106980641
# P-value: 7.582817195724622e-91
# 197
# Chisquare reduced: 4.603310714203372
# Fitted parameters: [1.97982717e+02 9.36567601e-12 2.84337160e-10]
# Covariance matrix: [[ 2.10208505e+00 -1.48101817e-19 -2.01260923e-12]
#  [-1.48101817e-19  2.89041271e-24  1.96492928e-31]
#  [-2.01260923e-12  1.96492928e-31  5.78082536e-24]]
# Chisquare: 256.18283945796475
# P-value: 0.003873303085566372
# 197
# Chisquare reduced: 1.3004205048627653

# %% [markdown]
# you fail to reject the null hypothesis and conclude that there is no significant difference between the observed and expected frequencies.

# %%
import math

def expo(x, a, b,c):
    retval=a * np.exp(-x*b) + c
    return retval


x=np.array(CFD)
y=s
# Fit linear model with curve_fit
popt, pcov = curve_fit(expo, x, y,sigma=ds,absolute_sigma=False,p0=[4.6e-9,0.07,2.68167447e-10])

# Print fitted parameters and covariance matrix
print("Fitted parameters:", popt)
print("Covariance matrix:", pcov)

# Plot scatter plot and fitted line
plt.errorbar(CFD, s,yerr=ds, fmt='o')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("expo regression fit")

plt.plot(x,expo(x,*popt), 'r')
plt.show()


'''
x_test = np.linspace(20, max(CFD), 1000)
y_test = (expo(x_test,4.6e-9,0.07,2.68167447e-10 ))
plt.plot(x_test, y_test, 'y-', label="Fitted curve")
plt.legend()
plt.show()
'''
# Calculate expected frequencies from fitted function
expected = expo(x, *popt)
# Scale expected frequencies by ratio of sums
ratio = sum(y) / sum(expected)
expected = expected * ratio


# Calculate chisquare and p-value
chisq, p = chisquare(y, expected)



# Print results
print("Chisquare:", chisq)
print("P-value:", p)

# Calculate chisquare reduced

dof= len(x) - 3
print(dof)
chisq_red = chisq / dof
print("Chisquare reduced:", chisq_red)
plt.show()
# Out:
# Fitted parameters: [3.53547236e-09 6.86678923e-02 2.68167447e-10]
# Covariance matrix: [[1.87034475e-18 1.15159868e-11 6.86819945e-21]
#  [1.15159868e-11 8.35106585e-05 6.51301564e-14]
#  [6.86819945e-21 6.51301564e-14 7.72723644e-23]]
# Chisquare: 1.8856952821142565e-10
# P-value: 1.0
# 4
# Chisquare reduced: 4.714238205285641e-11
